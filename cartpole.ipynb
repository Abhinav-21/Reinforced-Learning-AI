# %% [markdown]
# <h1 align='center' style='color:cyan'><b>CART-POLE-v0</b></h1>

# %% [markdown]
# <h3><b>IMPORTING REQUIRED MODULES</b></h3>

# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# <h3><b>CREATING THE ENVIRONMENT</b></h3>

# %%
environment_name = "CartPole-v0"
log_path = os.path.join("Training", "Logs")

# Create the environment

env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])

# %% [markdown]
# <h3><b>TRAINING AND SAVING MODEL</b></h3>

# %%
# Create the PPO model
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path)

# Train the model
model.learn(total_timesteps=30000)

# Save the trained model
PPO_path = os.path.join("Training", "Saved_Models", "PPO_Model_Cartpole")
model.save(PPO_path)
# Out:
# Using cpu device
# Logging to Training\Logs\PPO_51
# -----------------------------
# | time/              |      |
# |    fps             | 993  |
# |    iterations      | 1    |
# |    time_elapsed    | 2    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 751         |
# |    iterations           | 2           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009255754 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00373     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.27        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0177     |
# |    value_loss           | 54.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 689         |
# |    iterations           | 3           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008799162 |
# |    clip_fraction        | 0.0571      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.67       |
# |    explained_variance   | 0.0607      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.016      |
# |    value_loss           | 40.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 669         |
# |    iterations           | 4           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012742075 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.31        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.7        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0244     |
# |    value_loss           | 44          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 654        |
# |    iterations           | 5          |
# |    time_elapsed         | 15         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.00896048 |
# |    clip_fraction        | 0.0783     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.605     |
# |    explained_variance   | 0.228      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 26.9       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0163    |
# |    value_loss           | 60.4       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 646         |
# |    iterations           | 6           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.008746646 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.6        |
# |    explained_variance   | 0.32        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 29          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 63          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 641          |
# |    iterations           | 7            |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0054180846 |
# |    clip_fraction        | 0.0457       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.589       |
# |    explained_variance   | 0.552        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.2         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00975     |
# |    value_loss           | 56.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 636          |
# |    iterations           | 8            |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0064425236 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.589       |
# |    explained_variance   | 0.495        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.1         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00847     |
# |    value_loss           | 53.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 9           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.004116373 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.665       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.4        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 36.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 629         |
# |    iterations           | 10          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006796926 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.589      |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.8         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00651    |
# |    value_loss           | 26.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 623         |
# |    iterations           | 11          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006345415 |
# |    clip_fraction        | 0.0676      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.571      |
# |    explained_variance   | 0.516       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.542       |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00335    |
# |    value_loss           | 10.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 617         |
# |    iterations           | 12          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.004840728 |
# |    clip_fraction        | 0.0379      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.625       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.7        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00621    |
# |    value_loss           | 40.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 13           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0066331364 |
# |    clip_fraction        | 0.0519       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0.278        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.2         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00839     |
# |    value_loss           | 25.9         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 14           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0062369583 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.521       |
# |    explained_variance   | 0.135        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.659        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00203     |
# |    value_loss           | 3.15         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 15          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.006899665 |
# |    clip_fraction        | 0.0487      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.5        |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.154       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00488    |
# |    value_loss           | 2.02        |
# -----------------------------------------

# %% [markdown]
# <h3><b>TESTING THE MODEL</b></h3>

# %%
# Load the saved model
PPO_path = os.path.join("Training", "Saved_Models", "PPO_Model_Cartpole")
model = PPO.load(PPO_path, env=env)

# Create a new environment for evaluation
env = gym.make(environment_name, render_mode='human')

obs, info = env.reset(seed=123, options={})
done = False
score = 0 

while not done:
    env.render()
    action, _ = model.predict(obs)
    obs, reward, terminated, truncated, info = env.step(action)
    score += reward
    done = terminated or truncated
    
print(f'Score:{score}')

env.close()
# Out:
# Score:200.0
